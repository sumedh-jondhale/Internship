# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\dell\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dell\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dell\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
import time
from selenium.common.exceptions import NoSuchElementException
import re

# %% [markdown]
# # Q1

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
#Rank=[ ]
#Name=[ ]
#Artist=[ ]//a[@class="mw-redirect"]
#Upload_date=[ ]
#Views=[ ]//a[@class="mw-redirect"]

# %%
nameurl=[ ]
#for nameurl in range:
for url in name:
    url=driver.find_elements(By.XPATH,'//th[@class="headerSort"]//abbr')
    for i in url:
        nameurl.append(i.get_attribute("href"))

# %%
len(nameurl)
# Out:
# 0

# %% [markdown]
# # Q2

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
international=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
matchtitle=[ ]
series=[ ]
place=[ ]
date=[ ]
time=[ ]

# %%
title_tag=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[1]/h5[2]/span')
for i in title_tag:
    matchtitle.append(i.text)
    
series_tag=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[4]/div')
for i in series_tag:
    series.append(i.text)
    
place_tag=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[4]/div/span[2]')
for i in place_tag:
    place.append(i.text)
    
date_tag=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[1]/div/div[1]/h5')
for i in date_tag:
    date.append(i.text)
    
time_tag=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[1]/div/div[2]/h5')
for i in time_tag:
    time.append(i.text)

# %%
import pandas as pd
df=pd.DataFrame({'Title':matchtitle, 'Series':series, 'Place':place, 'Date':date, 'Time':time})
df
# Out:
#                                         Title  \
# 0  AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                Series              Place         Date  \
# 0  1st ODI - Wankhede Stadium, Mumbai  Wankhede Stadium,  17 MAR 2023
#
#           Time
# 0  1:30 PM IST

# %% [markdown]
# # Q3

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
economy=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

# %%
india=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
india.click()

# %%
states=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
states.click()

# %%
rank=[ ]
state=[ ]
GSDP1819=[ ]
GSDP1920=[ ]
share=[ ]
GDP=[ ]

# %%
rank_tag=driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in rank_tag[0:33]:
    rank.append(i.text)
    
state_tag=driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in state_tag[0:33]:
    state.append(i.text)
    
GSDP1819_tag=driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
for i in GSDP1819_tag[0:33]:
    GSDP1819.append(i.text)
    
GSDP1920_tag=driver.find_elements(By.XPATH,'/html/body/div[3]/div[2]/div[5]/div[1]/div/table/thead/tr[2]/th[1]')
for i in GSDP1920_tag[0:33]:
    GSDP1920.append(i.text)
    
share_tag=driver.find_elements(By.XPATH,'//td[5][@class="data"]')
for i in share_tag[0:33]:
    share.append(i.text)
    
GDP_tag=driver.find_elements(By.XPATH,'//td[6][@class="data"]')
for i in GDP_tag[0:33]:
    GDP.append(i.text)

# %%
import pandas as pd
df=pd.DataFrame({'Rank':rank, 'State':state, 'GSDP1819':GSDP1819, 'Share':share})
df[0:33]
# Out:
#    Rank                      State   GSDP1819   Share
# 0     1                Maharashtra  2,632,792  13.94%
# 1     2                 Tamil Nadu  1,630,208   8.63%
# 2     3              Uttar Pradesh  1,584,764   8.39%
# 3     4                    Gujarat  1,502,899   7.96%
# 4     5                  Karnataka  1,493,127   7.91%
# 5     6                West Bengal  1,089,898   5.77%
# 6     7                  Rajasthan    942,586   4.99%
# 7     8             Andhra Pradesh    862,957   4.57%
# 8     9                  Telangana    861,031   4.56%
# 9    10             Madhya Pradesh    809,592   4.29%
# 10   11                     Kerala    781,653   4.14%
# 11   12                      Delhi    774,870   4.10%
# 12   13                    Haryana    734,163   3.89%
# 13   14                      Bihar    530,363   2.81%
# 14   15                     Punjab    526,376   2.79%
# 15   16                     Odisha    487,805   2.58%
# 16   17                      Assam    315,881   1.67%
# 17   18               Chhattisgarh    304,063   1.61%
# 18   19                  Jharkhand    297,204   1.57%
# 19   20                Uttarakhand    245,895   1.30%
# 20   21            Jammu & Kashmir    155,956   0.83%
# 21   22           Himachal Pradesh    153,845   0.81%
# 22   23                        Goa     73,170   0.39%
# 23   24                    Tripura     49,845   0.26%
# 24   25                 Chandigarh     42,114   0.22%
# 25   26                 Puducherry     34,433   0.18%
# 26   27                  Meghalaya     33,481   0.18%
# 27   28                     Sikkim     28,723   0.15%
# 28   29                    Manipur     27,870   0.15%
# 29   30                   Nagaland     27,283   0.14%
# 30   31          Arunachal Pradesh     24,603   0.13%
# 31   32                    Mizoram     22,287   0.12%
# 32   33  Andaman & Nicobar Islands          -       -

# %% [markdown]
# # Q4

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get(" https://github.com/")

# %%
opensource=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]')
opensource.click()

# %%
trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
trending.click()

# %%
title=[ ]
description=[ ]
count=[ ]
language=[ ]

# %%
title_tag=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]//a')
for i in title_tag:
    title.append(i.text)
    
description_tag=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description_tag:
    description.append(i.text)
    
count_tag=driver.find_elements(By.XPATH,'//span[@class="d-inline-block mr-3"]')
for i in count_tag:
    count.append(i.text)
    
language_tag=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in language_tag:
    language.append(i.text)

# %%
import pandas as pd
df=pd.DataFrame({'Title':title, 'Description':description, 'Count':count})
df
# Out:
#                                       Title  \
# 0            deep-diver / Alpaca-LoRA-Serve
# 1                           BloopAI / bloop
# 2                           GerevAI / gerev
# 3        dair-ai / Prompt-Engineering-Guide
# 4     mayooear / gpt4-pdf-chatbot-langchain
# 5                 mckaywrigley / chatbot-ui
# 6                       keijiro / AICommand
# 7                 pelennor2170 / NAM_models
# 8                   modelscope / modelscope
# 9   nichtdax / awesome-totally-open-chatgpt
# 10      PlexPt / awesome-chatgpt-prompts-zh
# 11                   cocktailpeanut / dalai
# 12             Leizhenpeng / feishu-chatgpt
# 13                   josStorer / chatGPTBox
# 14                    hwchase17 / langchain
# 15              f / awesome-chatgpt-prompts
# 16              microsoft / semantic-kernel
# 17                    PlexPt / chatgpt-java
# 18                mymusise / ChatGLM-Tuning
# 19                     lensterxyz / lenster
# 20                     chidiwilliams / buzz
# 21                          Ciphey / Ciphey
# 22                         raysan5 / raylib
# 23                         Beomi / KoAlpaca
# 24                      tloen / alpaca-lora
#
#                                           Description     Count
# 0                      Alpaca-LoRA as Chatbot service  Built by
# 1   bloop is a fast code search engine written in ...  Built by
# 2     🧠 AI-powered search engine for your workplace 🔎  Built by
# 3   🐙 Guides, papers, lecture, notebooks and resou...  Built by
# 4         GPT4 & LangChain Chatbot for large PDF docs  Built by
# 5   A ChatGPT clone for running locally in your br...  Built by
# 6               ChatGPT integration with Unity Editor  Built by
# 7   A repository collecting model files for Neural...  Built by
# 8   ModelScope: bring the notion of Model-as-a-Ser...  Built by
# 9      A list of totally open alternatives to ChatGPT  Built by
# 10                ChatGPT 中文调教指南。各种场景使用指南。学习怎么让它听你的话。  Built by
# 11  The simplest way to run LLaMA on your local ma...  Built by
# 12  🎒飞书 ×（GPT-3.5 + DALL·E + Whisper）= 飞一般的工作体验 🚀 ...  Built by
# 13  Integrating ChatGPT into your browser deeply, ...  Built by
# 14  ⚡ Building applications with LLMs through comp...  Built by
# 15  This repo includes ChatGPT prompt curation to ...  Built by
# 16  Integrate cutting-edge LLM technology quickly ...  Built by
# 17         ChatGPT Java SDK。支持 GPT3.5、 GPT4 API。开箱即用。  Built by
# 18              一种平价的chatgpt实现方案, 基于ChatGLM-6B + LoRA  Built by
# 19  Lenster is a decentralized, and permissionless...  Built by
# 20  Buzz transcribes and translates audio offline ...  Built by
# 21  ⚡ Automatically decrypt encryptions without kn...  Built by
# 22  A simple and easy-to-use library to enjoy vide...  Built by
# 23  KoAlpaca: Korean Alpaca Model based on Stanfor...  Built by
# 24           Instruct-tune LLaMA on consumer hardware  Built by

# %% [markdown]
# # Q5

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get("https:/www.billboard.com/")

# %%
charts=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]')
charts.click()

# %%
viewchart=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
viewchart.click()

# %%
song=[ ]
artist=[ ]
lastweek=[ ]
peakrank=[ ]
weekboard=[ ]

# %%
song_tag=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]//h3')
for i in song_tag:
    song.append(i.text)
    
#artist_tag=driver.find_elements(By.XPATH,'')
#for i in artist_tag:
    #artist.append(i.text)
    
lastweek_tag=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]//span')
for i in lastweek_tag:
    lastweek.append(i.text)

# %%
import pandas as pd
df=pd.DataFrame({'Lastweek':lastweek})
df
# Out:
#     Lastweek
# 0          5
# 1          6
# 2          2
# 3          8
# 4          3
# ..       ...
# 395       19
# 396       78
# 397        9
# 398       81
# 399        7
#
# [400 rows x 1 columns]

# %% [markdown]
# # Q6

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare")

# %%
#site is not working

# %% [markdown]
# # Q7

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
Name=[ ]
Year_span=[ ]
Genre=[ ]
Run_time=[ ]
Ratings=[ ]
Votes=[ ]

# %%
name_tag=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]//a')
for i in name_tag:
    Name.append(i.text)
    
year_tag=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in year_tag:
    Year_span.append(i.text)
    
genre_tag=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in genre_tag:
    Genre.append(i.text)
    
runtime_tag=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in runtime_tag:
    Run_time.append(i.text)
    
rating_tag=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in rating_tag:
    Ratings.append(i.text)
    
votes_tag=driver.find_elements(By.XPATH,'//span[@name="nv"]')
for i in votes_tag:
    Votes.append(i.text)

# %%
import pandas as pd
df=pd.DataFrame({'name':Name, 'year':Year_span, 'genre':Genre, 'runtime':Run_time, 'rating':Ratings, 'votes':Votes})
df
# Out:
#                               name         year                     genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     runtime rating      votes
# 0    57 min    9.2  2,138,618
# 1    51 min    8.7  1,223,488
# 2    44 min    8.1  1,015,283
# 3    60 min    7.5    299,061
# 4    43 min    7.6    257,919
# ..      ...    ...        ...
# 95   42 min    7.4     51,025
# 96   50 min    7.8     63,033
# 97   42 min    8.1    204,974
# 98   45 min    7.1     42,478
# 99  572 min    8.6    253,636
#
# [100 rows x 6 columns]

# %% [markdown]
# # Q8

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
alldata=driver.find_element(By.XPATH,'//span[@class="whitetext"]//b')
alldata.click()

# %%
Dataset_name=[ ]
Data_type=[ ]
Task=[ ]
Attribute_type=[ ]
Noofinstances=[ ]
Noofattribute=[ ]
Year=[ ]

# %%
name_tag=driver.find_elements(By.XPATH,'//p[@class="normal"]//b')
for i in name_tag:
    Dataset_name.append(i.text)
    
type_tag=driver.find_elements(By.XPATH,'//p[2][@class="normal"]')
for i in type_tag:
    Data_type.append(i.text)

# %%
len(Data_type)
# Out:
# 0

# %%
import pandas as pd
df=pd.DataFrame({'Dataset Type':Data_type})
df
# Out:
# Empty DataFrame
# Columns: [Dataset Type]
# Index: []

# %% [markdown]
# # Q9

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
search_Data_science = driver.find_element(By.XPATH,"//input[@class='sugInp']")
search_Data_science.send_keys('Data Science')

# %%
button=driver.find_element(By.XPATH,'//button[@class="fl qsbSrch blueBtn"]')
button.click()

# %%
Name=[ ]
Designation=[ ]
Company=[ ]
Skills=[ ]
Location=[ ]

# %%
try:
    name_tag=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for i in name_tag:
        Name.append(i.text)
    
    designation_tag=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for i in designation_tag:
        Designation.append(i.text)
    
    company_tag=driver.find_elements(By.XPATH,'//a[2][@class="ellipsis"]')
    for i in company_tag:
        Company.append(i.text)

    location_tag=driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
    for i in location_tag:
        Location.append(i.text)
        
    skills_tag=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in skills_tag:
        Skills.append(i.text)
        
except NoSuchElementException:
    Name.append('-')
    Designation('-')
    Location.append('-')
    Skills('-')
    Company('-')

# %%
import pandas as pd 
df=pd.DataFrame({'Name':Name, 'Desgination':Designation, 'Skills':Skills, 'Company':Company})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                               Deeparchi Sharma
# 27                                  Azahar Shaikh
# 28                                          Manas
# 29                                          kumar
# 30                                   Sunil Vedula
# 31                                    Rajat Kumar
# 32                                Dhruv Dev Dubey
# 33                                  Avnish Mishra
# 34                                      Jayanth N
# 35                                         Avodha
# 36                                    Priya Khare
# 37                                    Amit Sharma
# 38                                          Kanan
# 39                           Shashikant Chaudhary
# 40                                           Brad
# 41                                   Rutuja Pawar
# 42                            Madhusudhan Sridhar
# 43                                    Ankit Sinha
# 44                                 Gaurav Chouhan
# 45                                   Rashi Kacker
# 46                                        Ashwini
# 47                                   Balaji Kolli
# 48                                 Rajani Nagaraj
# 49                                    ROHIT Kumar
#
#                                    Desgination  \
# 0                                   HR Manager
# 1                            Company Recruiter
# 2                                   Company HR
# 3                            Company Recruiter
# 4                                  Founder CEO
# 5                  Recruitment Lead Consultant
# 6                            Programme Manager
# 7                             HR Administrator
# 8                                     Director
# 9                               Human Resource
# 10                            Executive Hiring
# 11                                  Company HR
# 12                                  Company HR
# 13                                HR Team Lead
# 14                                  HR Manager
# 15                                  HR Manager
# 16                                HR Executive
# 17                        Assistant Manager HR
# 18         Senior Executive Talent Acquisition
# 19                                HR Executive
# 20                  Manager Talent Acquisition
# 21                                     HR Head
# 22                                  HR MANAGER
# 23                                HR Recruiter
# 24                                HR Recruiter
# 25                     Manager Human Resources
# 26                           Company Recruiter
# 27                           Company Recruiter
# 28                     Lead Talent acquisition
# 29                                  Proprietor
# 30                                         CEO
# 31                                 Founder CEO
# 32                    Company Recruitment Head
# 33  Senior Technical &amp; Corporate Recruiter
# 34                             Project Manager
# 35              Business Development Associate
# 36                              Senior Manager
# 37                                  Consultant
# 38                senior technology instructor
# 39                    HR Recruiter/HR Excutive
# 40               Manager, Technical Recruiting
# 41                         Technical Recruiter
# 42                             Erp Implementer
# 43                              Head Analytics
# 44                     Chief Technical Officer
# 45                          Sr Product Manager
# 46                    Director Global Delivery
# 47                                  Co Founder
# 48                                  HR Manager
# 49                                   Architect
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 11  Business Intelligence, Data Warehousing, Data ...
# 12  Office Administration, Hr Administration, tele...
# 13  Social Media, digital media maketing, seo, smm...
# 14  Oracle Dba, Data Science, Data Warehousing, ET...
# 15     Big Data, Hadoop, Data Analytics, Data Science
# 16               Data Science, Python, Data Analytics
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Research, Digital Marketing, Analytics, Softwa...
# 27  Data Science, Artificial Intelligence, Machine...
# 28  Software Architecture, Vp Engineering, Product...
# 29  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 30  Signal Processing, Machine Learning, Neural Ne...
# 31  Web Technologies, Project Management, Software...
# 32  Server Administartion, Verilog, Vhdl, Digital ...
# 33  Data Science, Machine Learning, Deep Learning,...
# 34  Data Analytics, Managed Services, Team Leading...
# 35  Ethical Hacking, Security Operations Center, S...
# 36  Data Science, Artificial Intelligence, analyti...
# 37  Machine Learning, Artificial Intelligence, Dat...
# 38  C, C++, Artificial Intelligence, Python, Php, ...
# 39  Relationship Management, Retail Sales, Private...
# 40                 Data Science, Software Engineering
# 41  Data Science, Big Data Analytics, Digital Mark...
# 42                  Data Science, Recruitment, Salary
# 43  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 44  Software Development, Business Intelligence, B...
# 45                   Data Science, Node.js, Angularjs
# 46  Data Science, Media Marketing, Resource Planni...
# 47  Data Analysis, Learning, Data Science, Compute...
# 48  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 49  Software Development, Core Java, Unit Testing,...
#
#                                            Company
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                              Innominds Software
# 11                                        MoneyTap
# 12              QuantMagnum Technologies Pvt. Ltd.
# 13                               SocialPrachar.com
# 14                   Infinitive Software Solutions
# 15                                  BISP Solutions
# 16                             Codeachive learning
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                                          ZIGRAM
# 27                 NEAL ANALYTICS SERVICES PVT LTD
# 28      Autumn Leaf Consulting Services Private...
# 29                                         trainin
# 30                            Nanoprecise Sci Corp
# 31                  R.S Consultancy &amp; Services
# 32                               NETAPS FOUNDATION
# 33                   RMS Risk Management Solutions
# 34        Dollarbird Information Services Pvt, Ltd
# 35                              Nikitha Palaparthi
# 36                          Independent Consultant
# 37                                 ASCO consulting
# 38                                         NY INST
# 39  3D India Staffing Research &amp; Consulting...
# 40                                     O.C. Tanner
# 41                                   Demand Matrix
# 42                             MADHUSUDHAN SRIDHAR
# 43                                  Suntech Global
# 44                        Strategic Consulting Lab
# 45                            Impel Labs Pvt. Ltd.
# 46                                    MRP Advisers
# 47                   Saras Solutions India Pvt Ltd
# 48                                     WildJasmine
# 49                             LNT Private Limited
